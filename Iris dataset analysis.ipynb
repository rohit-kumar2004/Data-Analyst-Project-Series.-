# %%
                       iris dataset

# %%
import pandas as pd

df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
                                            EDA analysis(data visulaization)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.countplot(x='Species', data=df, )
plt.show()

# %%
We will see the relationship between the sepal length and sepal width and also between petal length and petal width.

# %%
2)Comparing Sepal Length and Sepal Width

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',
                hue='Species', data=df, )
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
From the above plot, we can infer that – 

Species Setosa has smaller sepal lengths but larger sepal widths.
Versicolor Species lies in the middle of the other two species in terms of sepal length and width
Species Virginica has larger sepal lengths but smaller sepal widths.

# %%
 3) Comparing Petal Length and Petal Width

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm',
                hue='Species', data=df, )
 

plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
From the above plot, we can infer that – 

Species Setosa has smaller petal lengths and widths.
Versicolor Species lies in the middle of the other two species in terms of petal length and width
Species Virginica has the largest of petal lengths and widths.

# %%
 Histograms allow seeing the distribution of data for various columns. It can be used for uni as well as bi-variate analysis. so now i create a histogram  for this dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
fig, axes = plt.subplots(2, 2, figsize=(10,10))
 
axes[0,0].set_title("Sepal Length")
axes[0,0].hist(df['SepalLengthCm'], bins=7)
 
axes[0,1].set_title("Sepal Width")
axes[0,1].hist(df['SepalWidthCm'], bins=5);
 
axes[1,0].set_title("Petal Length")
axes[1,0].hist(df['PetalLengthCm'], bins=6);
 
axes[1,1].set_title("Petal Width")
axes[1,1].hist(df['PetalWidthCm'], bins=6);

# %%
From the above plot, we can see that – 
The highest frequency of the sepal length is between 30 and 35 which is between 5.5 and 6
The highest frequency of the sepal Width is around 70 which is between 3.0 and 3.5
The highest frequency of the petal length is around 50 which is between 1 and 2
The highest frequency of the petal width is between 40 and 50 which is between 0.0 and 0.5

# %%
now We can use boxplots to see how the categorical value of distributed with other numerical values.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
def graph(y):
    sns.boxplot(x="Species", y=y, data=df)
 
plt.figure(figsize=(10,10))
     


plt.subplot(221)
graph('SepalLengthCm')
 
plt.subplot(222)
graph('SepalWidthCm')
 
plt.subplot(223)
graph('PetalLengthCm')
 
plt.subplot(224)
graph('PetalWidthCm')
 
plt.show()

# %%
From the above graph, we can see that – 
Species Setosa has the smallest features and less distributed with some outliers.
Species Versicolor has the average features.
Species Virginica has the highest features

# %%
 handling outliers- There are many ways to detect the outliers, and the removal process is the data frame same as removing a data item from the panda’s dataframe.
let’s consider this dataset and let’s plot the boxplot for the SepalWidthCm column.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
# Load the dataset
df = pd.read_csv('Iris.csv')
 
sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
In the above graph, the values above 4 and below 2 are acting as outliers.

# %%
conclusion: The conclusion drawn from an Exploratory Data Analysis (EDA) of the Iris dataset using Python provides valuable insights
into the characteristics of the dataset. Here are some possible conclusions based on common analysis performed during EDA:
1)Sepal lengths are generally higher for Virginica, followed by Versicolor and Setosa.
2)Setosa tends to have wider sepals compared to the other two species.
3)Outliers may be present in the dataset, particularly in features like sepal width.
4)Positive correlations exist between petal length and petal width, as well as between sepal length and petal length.
5)Negative correlations may be observed between sepal width and both petal length and width.
6)Petal lengths and widths are usually highest for Virginica, followed by Versicolor and Setosa.
